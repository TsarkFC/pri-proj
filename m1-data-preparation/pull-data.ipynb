# %% [markdown]
# # Pulling pages and their mementos from Arquivo.pt
#
# 1. Search for unique URLs in the specified domain
# 2. For each of the URLs that were found, find the stored versions (mementos)

# %%
import requests, json, time, re

websites = {
    "noticias_ao_minuto": {
        "url": "http://noticiasaominuto.com",
        "article_verification_regex": re.compile("^(https:\/\/noticiasaominuto\.com\/[a-z0-9-%]+\/[0-9]+\/[a-z0-9-%]+)(?:\?.*)?$")
    }, 
    "publico": {
        "url": "http://publico.pt",
        "article_verification_regex": re.compile("^(http:\/\/publico\.pt\/[0-9]+\/[0-9]+\/[0-9]+\/[a-z0-9-%]+\/[a-z0-9-%]+\/[a-z0-9-%]+)(?:\?.*)?$")
    }
}
start_domain = "20180101000000"
end_domain = "20211101000000"

results = { identifier: requests.get(f"https://arquivo.pt/textsearch?q=&siteSearch={website['url']}&maxItems=2000&from={start_domain}&to={end_domain}&dedupValue=1&dedupField=url").json()
               for identifier, website in websites.items() }

# %%
amount_of_pages = { identifier: len(result["response_items"]) for identifier, result in results.items() }

print("Amount of pages per website: " + str(amount_of_pages))
# Out:
# Amount of pages per website: {'noticias_ao_minuto': 1244, 'publico': 487}

# %%
total_amount_of_pages = { identifier: 0 for identifier in websites.keys()}

output = {}

# TODO add progress bar?
for identifier, result in results.items():
    print(f"---------- {identifier}")
    output[identifier] = {}
    for item in result["response_items"]:
        url = item["originalURL"]
        
        match = websites[identifier]["article_verification_regex"].match(url)
        if not match:
            print(f"NOT an article: {url}")
            continue
        
        base_url = match.group(1) # this gets the first part of the url (without GET parameters)
        if base_url not in output[identifier]:
            output[identifier][base_url] = []
    
        cdx_response = None
        
        valid = True
        while True:
            cdx_response = requests.get(f"https://arquivo.pt/wayback/cdx?url={url}&from={start_domain}&to={end_domain}&output=json")
            if cdx_response.ok: break
            if cdx_response.status_code == 429: # limit of api calls
                time.sleep(10)
            else:
                valid = False
                print(f"Invalid url (url: {url}, status_code: {cdx_response.status_code})")
                break
        
        if not valid: continue
        
        # response is a string where each line is JSON for a memento object
        # ignoring last line because it is an empty string
        splitted = cdx_response.text.split("\n")[:-1]
        
        for memento in splitted:
            output[identifier][base_url].append(json.loads(memento)["timestamp"])
        
        total_amount_of_pages[identifier] += len(splitted)

print("Amount of pages (including mementos): " + str(total_amount_of_pages))

with open("data.json", "w") as file:
    json.dump(output, file, indent=4)
# Out:
# ---------- noticias_ao_minuto
# NOT an article: https://noticiasaominuto.com/
# NOT an article: https://noticiasaominuto.com/robots.txt
# NOT an article: https://noticiasaominuto.com/manifest.json
# ---------- publico
# NOT an article: http://publico.pt/
# NOT an article: http://publico.pt/troika
# NOT an article: http://publico.pt/2019/08/01/ciencia/entrevista/quantidade-emissoes-gases-estufa-permitimos-aviacao-absurda-1881906/embed?FromApp=1
# NOT an article: http://publico.pt/a-europa-que-conta-podcast
# NOT an article: http://publico.pt/acores/vila-franca-do-campo
# NOT an article: http://publico.pt/autor/micael-sousa
# NOT an article: http://publico.pt/aveiro/santa-maria-da-feira
# NOT an article: http://publico.pt/aveiro/sever-do-vouga
# NOT an article: http://publico.pt/aveiro/vagos
# NOT an article: http://publico.pt/braga/vizela
# NOT an article: http://publico.pt/europeias-2019/resultados
# NOT an article: http://publico.pt/p3/vicios
# NOT an article: http://publico.pt/roman-polanski
# NOT an article: http://publico.pt/setubal/alcacer-do-sal
# NOT an article: http://publico.pt/viseu/penedono
# NOT an article: http://publico.pt/woodstock
# NOT an article: http://publico.pt/aveiro/sao-joao-da-madeira
# NOT an article: http://publico.pt/braga/vieira-do-minho
# NOT an article: http://publico.pt/kanye-west
# NOT an article: http://publico.pt/reservado-ao-publico-podcast
# NOT an article: http://publico.pt/santarem/benavente
# NOT an article: http://publico.pt/santarem/sardoal
# NOT an article: http://publico.pt/serie-objectos-quase-obsoletos?page=2
# NOT an article: http://publico.pt/sl-benfica
# NOT an article: http://publico.pt/tinder
# NOT an article: http://publico.pt/ultimas/desporto?page=1
# NOT an article: http://publico.pt/universidade-catolica
# NOT an article: http://publico.pt/viana-do-castelo/ponte-da-barca
# NOT an article: http://publico.pt/ao-vivo
# NOT an article: http://publico.pt/cronica-vanessa
# NOT an article: http://publico.pt/economia/trabalho-e-emprego
# NOT an article: http://publico.pt/menores-em-risco
# NOT an article: http://publico.pt/p3/reino-unido
# NOT an article: http://publico.pt/porto/trofa
# NOT an article: http://publico.pt/sinn-fein
# NOT an article: http://publico.pt/taylor-swift
# NOT an article: http://publico.pt/tecnologia/telemoveis
# NOT an article: http://publico.pt/uniao-europeia
# NOT an article: http://publico.pt/vila-franca-de-xira
# NOT an article: http://publico.pt/culturaipsilon/teatro
# NOT an article: http://publico.pt/lisboa/sintra
# NOT an article: http://publico.pt/marta-temido
# NOT an article: http://publico.pt/pedro-nuno-santos
# NOT an article: http://publico.pt/sem-filtro
# NOT an article: http://publico.pt/sergio-rodrigues
# NOT an article: http://publico.pt/timorleste-20-anos-referendo
# NOT an article: http://publico.pt/universidades
# NOT an article: http://publico.pt/vinicultura
# NOT an article: http://publico.pt/castelo-branco/serta
# NOT an article: http://publico.pt/culturaipsilon/tv
# NOT an article: http://publico.pt/guarda/seia
# NOT an article: http://publico.pt/leiria/caldas-da-rainha
# NOT an article: http://publico.pt/madeira/ponta-do-sol
# NOT an article: http://publico.pt/pedro-santana-lopes
# NOT an article: http://publico.pt/presidente-da-republica
# NOT an article: http://publico.pt/refugiados
# NOT an article: http://publico.pt/rios
# NOT an article: http://publico.pt/robots.txt
# NOT an article: http://publico.pt/sofia-coppola
# NOT an article: http://publico.pt/sp-braga
# NOT an article: http://publico.pt/steven-soderbergh
# NOT an article: http://publico.pt/turismo
# NOT an article: http://publico.pt/verao-sustentavel?page=2
# NOT an article: http://publico.pt/violencia-no-desporto
# NOT an article: http://publico.pt/viseu/vouzela
# NOT an article: http://publico.pt/andre-silva
# NOT an article: http://publico.pt/aveiro/vale-de-cambra
# NOT an article: http://publico.pt/beja/serpa
# NOT an article: http://publico.pt/beja/vidigueira
# NOT an article: http://publico.pt/coimbra/soure
# NOT an article: http://publico.pt/desporto/raguebi
# NOT an article: http://publico.pt/desporto/running
# NOT an article: http://publico.pt/guarda/figueira-de-castelo-rodrigo
# NOT an article: http://publico.pt/porto/povoa-de-varzim
# NOT an article: http://publico.pt/quiz?page=2
# NOT an article: http://publico.pt/urbanismo
# NOT an article: http://publico.pt/autor/manuel-clementegap-year-portugal
# NOT an article: http://publico.pt/autor/vera-ramalho
# NOT an article: http://publico.pt/braga/terras-de-bouro
# NOT an article: http://publico.pt/legendary-tigerman
# NOT an article: http://publico.pt/pesquisa?query=
# NOT an article: http://publico.pt/portalegre/sousel
# NOT an article: http://publico.pt/revista-de-imprensa?page=2
# NOT an article: http://publico.pt/seguranca-social
# NOT an article: http://publico.pt/sindicatos
# NOT an article: http://publico.pt/autor/marco-robalo
# NOT an article: http://publico.pt/braganca/vimioso
# NOT an article: http://publico.pt/guarda/sabugal
# NOT an article: http://publico.pt/portalegre/castelo-de-vide
# NOT an article: http://publico.pt/recursos-naturais
# NOT an article: http://publico.pt/tecnologia/interactivo/teste-41
# NOT an article: http://publico.pt/utilizador/login?return=/utilizador/biblioteca
# NOT an article: http://publico.pt/autor/fernando-teixeira
# NOT an article: http://publico.pt/estudiop/interactivo/tem-certeza-sabe-alimentacao-gatinho-cachorro-9-48
# NOT an article: http://publico.pt/homo-sapiens
# NOT an article: http://publico.pt/madeira/ribeira-brava
# NOT an article: http://publico.pt/rodriguez
# NOT an article: http://publico.pt/setubal/sines
# NOT an article: http://publico.pt/triatlo
# NOT an article: http://publico.pt/braganca/vinhais
# NOT an article: http://publico.pt/britney-spears
# NOT an article: http://publico.pt/coimbra/pampilhosa-da-serra
# NOT an article: http://publico.pt/madeira/sao-vicente
# NOT an article: http://publico.pt/p3/vestuario
# NOT an article: http://publico.pt/santarem/ferreira-do-zezere
# NOT an article: http://publico.pt/setubal/transportes
# NOT an article: http://publico.pt/sondagem
# NOT an article: http://publico.pt/streaming
# NOT an article: http://publico.pt/tom-hanks
# NOT an article: http://publico.pt/autor/tomas-guerreiro
# NOT an article: http://publico.pt/coimbra/tabua
# NOT an article: http://publico.pt/lisboa/torres-vedras
# NOT an article: http://publico.pt/referendo
# NOT an article: http://publico.pt/televisao
# NOT an article: http://publico.pt/faro/silves
# NOT an article: http://publico.pt/portalegre/ponte-de-sor
# NOT an article: http://publico.pt/santarem/torres-novas
# NOT an article: http://publico.pt/v-guimaraes
# NOT an article: http://publico.pt/autor/ricardo-garcia
# NOT an article: http://publico.pt/desporto/tenis
# NOT an article: http://publico.pt/faro/tavira
# NOT an article: http://publico.pt/guarda/trancoso
# NOT an article: http://publico.pt/nacoes-unidas
# NOT an article: http://publico.pt/porto/santo-tirso
# NOT an article: http://publico.pt/ryanair
# NOT an article: http://publico.pt/solidariedade
# NOT an article: http://publico.pt/supertaca
# NOT an article: http://publico.pt/templates/shared/correccao.html
# NOT an article: http://publico.pt/autor/agencia-reuters
# NOT an article: http://publico.pt/europeias-2019/interactivo/qual-partido-mais-identifica
# NOT an article: http://publico.pt/porto/valongo
# NOT an article: http://publico.pt/sao-pedro-do-sul
# NOT an article: http://publico.pt/autor/publico-com-agencias
# NOT an article: http://publico.pt/lisboa/sobral-de-monte-agraco
# NOT an article: http://publico.pt/api/user/newsletter/add
# Amount of pages (including mementos): {'noticias_ao_minuto': 7391, 'publico': 3713}
